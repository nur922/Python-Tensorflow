# %%
import numpy as np
import pandas as pd
import seaborn as sbs
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_excel("Mobile-price.xlsx")
df
# Out:
#      Ratings   RAM    ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 0        4.3   4.0  128.0         6.00           48       13.0           4000
# 1        3.4   6.0   64.0         4.50           48       12.0           4000
# 2        4.3   4.0    4.0         4.50           64       16.0           4000
# 3        4.4   6.0   64.0         6.40           48       15.0           3800
# 4        4.5   6.0  128.0         6.18           35       15.0           3800
# ..       ...   ...    ...          ...          ...        ...            ...
# 802      3.8   6.0   32.0         4.54           48       12.0           2800
# 803      4.1   8.0   64.0         4.54           64        8.0           2500
# 804      4.4   3.0   32.0         6.20           48        1.0           3800
# 805      3.7  10.0   32.0         4.50           64        8.0           3500
# 806      3.5   6.0   32.0         4.50           64       15.0           1050
#
#      Price
# 0    24999
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ratings        807 non-null    float64
#  1   RAM            807 non-null    float64
#  2   ROM            807 non-null    float64
#  3   Mobile_Size    807 non-null    float64
#  4   Primary_Cam    807 non-null    int64
#  5   Selfi_Cam      807 non-null    float64
#  6   Battery_Power  807 non-null    int64
#  7   Price          807 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 50.6 KB

# %%
df.isnull().sum()
# Out:
# Ratings          0
# RAM              0
# ROM              0
# Mobile_Size      0
# Primary_Cam      0
# Selfi_Cam        0
# Battery_Power    0
# Price            0
# dtype: int64

# %%
df.describe()
# Out:
#           Ratings         RAM         ROM  Mobile_Size  Primary_Cam  \
# count  807.000000  807.000000  807.000000   807.000000   807.000000
# mean     4.112639    5.941760   64.390335     5.620660    47.821561
# std      0.367830    2.056359   53.868626     3.957409    11.155916
# min      2.800000    0.000000    2.000000     2.000000     5.000000
# 25%      3.900000    6.000000   32.000000     4.500000    48.000000
# 50%      4.100000    6.000000   32.000000     4.770000    48.000000
# 75%      4.400000    6.000000   64.000000     6.300000    48.000000
# max      4.800000   12.000000  256.000000    44.000000    64.000000
#
#         Selfi_Cam  Battery_Power          Price
# count  807.000000     807.000000     807.000000
# mean     8.868649    3278.859975   14269.167286
# std      4.547254     937.628801   23092.739983
# min      0.000000    1020.000000     479.000000
# 25%      8.000000    3000.000000     984.000000
# 50%      8.000000    3000.000000    1699.000000
# ...

# %%
ram_sifir_satirlar = df[df["RAM"] == 0]
print(ram_sifir_satirlar)
print(len(ram_sifir_satirlar))
# Out:
#      Ratings  RAM   ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 172      3.4  0.0  64.0         4.50           48        8.0           3000
# 396      3.7  0.0  64.0         4.54           64        8.0           3500
#
#      Price
# 172    595
# 396    949
# 2

# %%
df = df[df["RAM"] != 0]
df.describe()
# Out:
#           Ratings         RAM         ROM  Mobile_Size  Primary_Cam  \
# count  805.000000  805.000000  805.000000   805.000000   805.000000
# mean     4.114037    5.956522   64.391304     5.623395    47.801242
# std      0.367138    2.037423   53.935581     3.961946    11.155181
# min      2.800000    1.000000    2.000000     2.000000     5.000000
# 25%      3.900000    6.000000   32.000000     4.500000    48.000000
# 50%      4.100000    6.000000   32.000000     4.770000    48.000000
# 75%      4.400000    6.000000   64.000000     6.300000    48.000000
# max      4.800000   12.000000  256.000000    44.000000    64.000000
#
#         Selfi_Cam  Battery_Power          Price
# count  805.000000     805.000000     805.000000
# mean     8.870807    3278.931677   14302.700621
# std      4.552699     938.710367   23111.616602
# min      0.000000    1020.000000     479.000000
# 25%      8.000000    3000.000000     985.000000
# 50%      8.000000    3000.000000    1699.000000
# ...

# %%
cam_sifir=df[df["Selfi_Cam"]==0]
print(cam_sifir)
print(len(cam_sifir))
# Out:
#      Ratings  RAM   ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 38       3.6  6.0  32.0         4.54           38        0.0           1200
# 228      4.1  6.0  32.0         4.50           48        0.0           1050
# 237      3.9  6.0  32.0         4.54           48        0.0           3000
# 437      3.6  6.0  32.0         4.54           38        0.0           1200
# 505      3.6  6.0  32.0         4.54           38        0.0           1200
#
#      Price
# 38     945
# 228    849
# 237   1200
# 437    945
# 505    945
# 5

# %%
df=df[df["Selfi_Cam"]!=0]
df.describe()
# Out:
#          Ratings         RAM         ROM  Mobile_Size  Primary_Cam  \
# count  800.00000  800.000000  800.000000   800.000000   800.000000
# mean     4.11625    5.956250   64.593750     5.630216    47.837500
# std      0.36685    2.043785   54.042988     3.973380    11.173838
# min      2.80000    1.000000    2.000000     2.000000     5.000000
# 25%      3.90000    6.000000   32.000000     4.500000    48.000000
# 50%      4.10000    6.000000   35.000000     4.770000    48.000000
# 75%      4.40000    6.000000   64.000000     6.300000    48.000000
# max      4.80000   12.000000  256.000000    44.000000    64.000000
#
#         Selfi_Cam  Battery_Power          Price
# count  800.000000     800.000000     800.000000
# mean     8.926250    3289.862500   14385.987500
# std      4.512346     929.531511   23159.687479
# min      1.000000    1020.000000     479.000000
# 25%      8.000000    3000.000000     985.000000
# 50%      8.000000    3000.000000    1749.000000
# ...

# %%
len(df)
# Out:
# 800

# %%
df.sort_values("Price",ascending=False).head(10)
# Out:
#      Ratings   RAM    ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 131      4.4   6.0  128.0          6.3           48        1.0           3800
# 5        4.7   8.0  128.0          5.8           35       12.0           5000
# 417      4.7   8.0   64.0          5.8           35       12.0           5000
# 746      4.7   8.0   64.0          5.8           35       12.0           3500
# 273      4.7   8.0   64.0          5.8           35       12.0           3500
# 722      4.7   8.0   64.0          5.8           35       12.0           3500
# 525      4.7  12.0   64.0          5.8           35       12.0           3500
# 55       4.7  12.0  256.0          5.8           35       12.0           3800
# 48       4.7   8.0   64.0          6.5           35       12.0           3000
# 455      4.7   8.0   64.0          6.5           35       12.0           3500
#
#       Price
# 131  153000
# 5    140300
# 417  140300
# 746  140300
# 273  140300
# 722  140300
# 525  121300
# ...

# %%
df=df[df["Selfi_Cam"]!=1]
df.sort_values("Price",ascending=False).head(10)
# Out:
#      Ratings   RAM    ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 273      4.7   8.0   64.0          5.8           35       12.0           3500
# 722      4.7   8.0   64.0          5.8           35       12.0           3500
# 746      4.7   8.0   64.0          5.8           35       12.0           3500
# 5        4.7   8.0  128.0          5.8           35       12.0           5000
# 417      4.7   8.0   64.0          5.8           35       12.0           5000
# 55       4.7  12.0  256.0          5.8           35       12.0           3800
# 525      4.7  12.0   64.0          5.8           35       12.0           3500
# 745      4.7   8.0   64.0          6.5           35       12.0           3500
# 778      4.7   8.0   64.0          6.5           35       12.0           3500
# 48       4.7   8.0   64.0          6.5           35       12.0           3000
#
#       Price
# 273  140300
# 722  140300
# 746  140300
# 5    140300
# 417  140300
# 55   121300
# 525  121300
# ...

# %%
df.sort_values("Price").head(20)
# Out:
#      Ratings  RAM   ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 124      3.7  8.0  64.0         4.50           48        5.0           3000
# 143      3.2  6.0  64.0         4.50           64        8.0           3500
# 90       3.4  6.0  32.0         4.77           48        8.0           3000
# 231      3.4  6.0  64.0         4.50           48       14.0           3000
# 299      3.5  6.0  64.0         4.50           48        8.0           3000
# 269      3.4  6.0  64.0         4.50           48        8.0           3000
# 611      3.5  6.0  64.0         4.50           48        8.0           3000
# 354      3.5  6.0  64.0         4.50           48        5.0           3000
# 652      3.4  6.0  64.0         4.50           48        8.0           3000
# 213      3.1  6.0  32.0         4.50           48        8.0           3000
# 720      3.4  6.0  64.0         4.50           48        8.0           4700
# ...

# %%
df.corr()["Price"].sort_values()
# Out:
# Primary_Cam     -0.274691
# Mobile_Size      0.079190
# Selfi_Cam        0.080814
# RAM              0.288233
# Battery_Power    0.354959
# ROM              0.459726
# Ratings          0.571640
# Price            1.000000
# Name: Price, dtype: float64

# %%
cor_df=df.corr()
cor_index=cor_df["Price"].sort_values(ascending=False)
plt.figure(figsize=(10,6))
sbs.barplot(x=cor_index.values,y=cor_index.index)
plt.title("Price'ın korelasyonları")
plt.xlabel("korelasyon")
plt.ylabel("değişkenler")
plt.grid(True)
plt.show()

# %%
df=df.drop(["Selfi_Cam","Mobile_Size"],axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 779 entries, 0 to 806
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ratings        779 non-null    float64
#  1   RAM            779 non-null    float64
#  2   ROM            779 non-null    float64
#  3   Primary_Cam    779 non-null    int64
#  4   Battery_Power  779 non-null    int64
#  5   Price          779 non-null    int64
# dtypes: float64(3), int64(3)
# memory usage: 42.6 KB

# %%
sbs.displot(df["Price"])

# %%
len(df[df["Price"]>100000])
# Out:
# 17

# %%
df=df[df["Price"]<=100000]
len(df)
# Out:
# 762

# %%
len(df[df["Price"]<1000])
# Out:
# 219

# %%
len(df[df["Price"]<600])
# Out:
# 15

# %%
df=df[df["Price"]>600]
len(df)
# Out:
# 747

# %%
plt.scatter(x="Price",y="Primary_Cam",data=df)

# %%
plt.scatter(x="Price",y="Ratings",data=df)

# %%
df.groupby("Primary_Cam").count()
# Out:
#              Ratings  RAM  ROM  Battery_Power  Price
# Primary_Cam
# 5                  2    2    2              2      2
# 8                  9    9    9              9      9
# 16                 6    6    6              6      6
# 20                 5    5    5              5      5
# 25                11   11   11             11     11
# 26                 4    4    4              4      4
# 35                63   63   63             63     63
# 38                63   63   63             63     63
# 40                 3    3    3              3      3
# 48               419  419  419            419    419
# 64               162  162  162            162    162

# %%
len(df)
# Out:
# 747

# %%
df=df[df["Primary_Cam"]!=5]
df.groupby("Primary_Cam").count()
# Out:
#              Ratings  RAM  ROM  Battery_Power  Price
# Primary_Cam
# 8                  9    9    9              9      9
# 16                 6    6    6              6      6
# 20                 5    5    5              5      5
# 25                11   11   11             11     11
# 26                 4    4    4              4      4
# 35                63   63   63             63     63
# 38                63   63   63             63     63
# 40                 3    3    3              3      3
# 48               419  419  419            419    419
# 64               162  162  162            162    162

# %%
y=df["Price"].values

# %%
x=df.drop("Price",axis=1).values

# %%
x.shape
# Out:
# (745, 5)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test,y_train ,y_test=train_test_split(x,y , test_size=0.3 , random_state=20)

# %%
len(x_train)
# Out:
# 521

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
skaler=MinMaxScaler()

# %%
x_train=skaler.fit_transform(x_train)

# %%
x_test=skaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[0.44444444, 0.45454545, 0.11462451, 0.71428571, 0.39393939],
#        [0.5       , 0.45454545, 0.11462451, 1.        , 0.71717172],
#        [0.38888889, 0.45454545, 0.11462451, 1.        , 0.1010101 ],
#        ...,
#        [0.83333333, 0.63636364, 1.        , 0.71428571, 0.55555556],
#        [0.72222222, 0.45454545, 0.24110672, 0.71428571, 0.7979798 ],
#        [0.72222222, 0.27272727, 0.24110672, 0.53571429, 0.55555556]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense 
from tensorflow.keras.callbacks import EarlyStopping

# %%
model=Sequential()
model.add(Dense(150, activation="relu"))
model.add(Dense(75, activation="relu"))
model.add(Dense(75, activation="relu"))
model.add(Dense(75, activation="relu"))
model.add(Dense(10, activation="relu"))
model.add(Dense(1))

model.compile(optimizer="adam" , loss="mse")

# %%
early_Stop=EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

# %%
model.fit(x=x_train,y=y_train, validation_data=(x_test,y_test), batch_size=100 , epochs =300, callbacks=[early_Stop])
# Out:
# Epoch 1/300
# 6/6 [==============================] - 1s 40ms/step - loss: 345246176.0000 - val_loss: 387564896.0000
# Epoch 2/300
# 6/6 [==============================] - 0s 8ms/step - loss: 345235232.0000 - val_loss: 387548064.0000
# Epoch 3/300
# 6/6 [==============================] - 0s 7ms/step - loss: 345212928.0000 - val_loss: 387514176.0000
# Epoch 4/300
# 6/6 [==============================] - 0s 7ms/step - loss: 345169536.0000 - val_loss: 387440608.0000
# Epoch 5/300
# 6/6 [==============================] - 0s 8ms/step - loss: 345069984.0000 - val_loss: 387282592.0000
# Epoch 6/300
# 6/6 [==============================] - 0s 8ms/step - loss: 344864736.0000 - val_loss: 386959776.0000
# Epoch 7/300
# 6/6 [==============================] - 0s 7ms/step - loss: 344439392.0000 - val_loss: 386329344.0000
# Epoch 8/300
# 6/6 [==============================] - 0s 8ms/step - loss: 343648576.0000 - val_loss: 385140896.0000
# Epoch 9/300
# ...

# %%
loss=pd.DataFrame(model.history.history)

# %%
loss.plot()
# Out:
# <AxesSubplot:>

# %%
deney=model.predict(x_test)
# Out:
# 7/7 [==============================] - 0s 415us/step

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,deney)
# Out:
# 5535.871746063232

# %%
plt.scatter(y_test,deney)
plt.plot(y_test,y_test,"r-*")

# %%
veri=df.iloc[20]
veri
# Out:
# Ratings             3.8
# RAM                 6.0
# ROM                32.0
# Primary_Cam        48.0
# Battery_Power    3000.0
# Price            1349.0
# Name: 22, dtype: float64

# %%
veri=df.drop("Price",axis=1).iloc[20]
veri
# Out:
# Ratings             3.8
# RAM                 6.0
# ROM                32.0
# Primary_Cam        48.0
# Battery_Power    3000.0
# Name: 22, dtype: float64

# %%
veri=skaler.transform(veri.values.reshape(-1,5))
veri
# Out:
# array([[0.44444444, 0.45454545, 0.11462451, 0.71428571, 0.39393939]])

# %%
model.predict(veri)
# Out:
# 1/1 [==============================] - 0s 66ms/step
# array([[1588.3647]], dtype=float32)

# %%
type(y_test)
# Out:
# numpy.ndarray

# %%
type(deney)
# Out:
# numpy.ndarray

# %%
reg_model_diff = pd.DataFrame({'Actual value': y_test.ravel(), 'Predicted value': deney.ravel()})
reg_model_diff
# Out:
#      Actual value  Predicted value
# 0             930      1588.364624
# 1            1399      1827.852783
# 2            1699      3047.319824
# 3           42990     26275.326172
# 4            4277      2637.014648
# ..            ...              ...
# 219         59000     21503.611328
# 220          1099      1822.523438
# 221         38990     40235.738281
# 222         18499     15213.960938
# 223         14999     11993.969727
#
# [224 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(x_test)
y_pred
# Out:
# array([ 6.65785208e+01,  3.94967426e+02, -8.63877438e+03,  2.45715124e+04,
#        -2.97028671e+03,  7.93413997e+02,  5.22568645e+03,  1.78628116e+03,
#         3.71978738e+02,  1.45870119e+04,  3.08461162e+04,  1.78628116e+03,
#         1.81674315e+03,  1.50174420e+04, -2.97028671e+03,  4.30858210e+03,
#         3.50598381e+03,  3.51459573e+04,  6.65785208e+01,  1.11476066e+04,
#         3.80115621e+03,  3.85397410e+04,  6.65785208e+01,  1.79167992e+04,
#         4.30858210e+03,  2.51346056e+04,  1.96298304e+04,  3.87929941e+03,
#         1.87746708e+04,  5.22568645e+03,  2.58978405e+04,  4.97335076e+03,
#         5.22568645e+03,  1.77532397e+04,  5.22568645e+03,  1.78628116e+03,
#         1.48015098e+04,  5.22568645e+03,  3.80536757e+04,  5.90445457e+03,
#         2.00473613e+04,  3.64381344e+03,  2.78273303e+03,  2.78273303e+03,
#         1.55749792e+04, -1.36908765e+04,  2.72541677e+04,  3.18473330e+03,
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = rf.predict(x_test)
y_pred
# Out:
# array([  827.87888636,  2004.04      ,   970.64      , 24966.639     ,
#         2731.0915    ,  1106.58      ,  1139.67597589,   674.27066667,
#         1398.778     ,  2767.4725    , 33749.75666667,   674.27066667,
#          964.25626647, 20612.68685714,  2731.0915    ,  1057.65134918,
#         1147.49590011, 41988.14433333,   827.87888636,  1044.77633028,
#         1169.53449892, 37693.14017369,   827.87888636,  8511.17666667,
#         1057.65134918, 18019.28933333, 34443.08920635,  1284.4772207 ,
#        31262.66      ,  1139.67597589, 52818.1525    ,  1240.11996789,
#         1139.67597589, 18728.96      ,  1139.67597589,   674.27066667,
#        10907.32      ,  1139.67597589, 35255.99427794,  1406.04576007,
#        18993.47933333,  1108.61327228, 13070.25      , 13070.25      ,
#        23476.79      ,  8555.53547619, 66140.22845238,  2080.59975   ,
#         1176.54763736, 11722.3625    ,   827.87888636,   633.7       ,
# ...

# %%
reg_model_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred})
reg_model_diff
# Out:
#      Actual value  Predicted value
# 0             930       827.878886
# 1            1399      2004.040000
# 2            1699       970.640000
# 3           42990     24966.639000
# 4            4277      2731.091500
# ..            ...              ...
# 219         59000     19426.508119
# 220          1099      1852.720000
# 221         38990     35255.994278
# 222         18499     12667.700000
# 223         14999     15593.410000
#
# [224 rows x 2 columns]

# %%
plt.scatter(reg_model_diff['Predicted value'], reg_model_diff['Actual value'], alpha=0.5)
plt.plot(y_test,y_test,"r-*")
