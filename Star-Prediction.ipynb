# %%
import pandas as pd
import numpy as np
import seaborn as sbs
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("star_classification.csv")
df
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0      19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1      21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2      19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3      20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4      15.97711  15.54461    8102       301        3       137  6.891865e+18
# ...         ...       ...     ...       ...      ...       ...           ...
# 99995  21.30548  20.73569    7778       301        2       581  1.055431e+19
# 99996  19.75759  19.41526    7917       301        1       289  8.586351e+18
# 99997  17.69034  17.35221    5314       301        4       308  3.112008e+18
# 99998  19.07254  18.62482    3650       301        4       131  7.601080e+18
# 99999  20.00959  19.28075    3650       301        4        60  8.343152e+18
#
#         class  redshift  plate    MJD  fiber_ID
# 0      GALAXY  0.634794   5812  56354       171
# 1      GALAXY  0.779136  10445  58158       427
# 2      GALAXY  0.644195   4576  55592       299
# 3      GALAXY  0.932346   9149  58039       775
# 4      GALAXY  0.116123   6121  56187       842
# ...       ...       ...    ...    ...       ...
# 99995  GALAXY  0.000000   9374  57749       438
# 99996  GALAXY  0.404895   7626  56934       866
# 99997  GALAXY  0.143366   2764  54535        74
# 99998  GALAXY  0.455040   6751  56368       470
# 99999  GALAXY  0.542944   7410  57104       851
#
# [100000 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   obj_ID       100000 non-null  float64
#  1   alpha        100000 non-null  float64
#  2   delta        100000 non-null  float64
#  3   u            100000 non-null  float64
#  4   g            100000 non-null  float64
#  5   r            100000 non-null  float64
#  6   i            100000 non-null  float64
#  7   z            100000 non-null  float64
#  8   run_ID       100000 non-null  int64
#  9   rerun_ID     100000 non-null  int64
#  10  cam_col      100000 non-null  int64
#  11  field_ID     100000 non-null  int64
#  12  spec_obj_ID  100000 non-null  float64
#  13  class        100000 non-null  object
#  14  redshift     100000 non-null  float64
#  15  plate        100000 non-null  int64
#  16  MJD          100000 non-null  int64
#  17  fiber_ID     100000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 13.7+ MB

# %%
df.isnull().sum()
# Out:
# obj_ID         0
# alpha          0
# delta          0
# u              0
# g              0
# r              0
# i              0
# z              0
# run_ID         0
# rerun_ID       0
# cam_col        0
# field_ID       0
# spec_obj_ID    0
# class          0
# redshift       0
# plate          0
# MJD            0
# fiber_ID       0
# dtype: int64

# %%
df.describe()
# Out:
#              obj_ID          alpha          delta              u  \
# count  1.000000e+05  100000.000000  100000.000000  100000.000000
# mean   1.237665e+18     177.629117      24.135305      21.980468
# std    8.438560e+12      96.502241      19.644665      31.769291
# min    1.237646e+18       0.005528     -18.785328   -9999.000000
# 25%    1.237659e+18     127.518222       5.146771      20.352353
# 50%    1.237663e+18     180.900700      23.645922      22.179135
# 75%    1.237668e+18     233.895005      39.901550      23.687440
# max    1.237681e+18     359.999810      83.000519      32.781390
#
#                    g              r              i              z  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       20.531387      19.645762      19.084854      18.668810
# std        31.750292       1.854760       1.757895      31.728152
# min     -9999.000000       9.822070       9.469903   -9999.000000
# 25%        18.965230      18.135828      17.732285      17.460677
# 50%        21.099835      20.125290      19.405145      19.004595
# 75%        22.123767      21.044785      20.396495      19.921120
# max        31.602240      29.571860      32.141470      29.383740
#
#               run_ID  rerun_ID        cam_col       field_ID   spec_obj_ID  \
# count  100000.000000  100000.0  100000.000000  100000.000000  1.000000e+05
# mean     4481.366060     301.0       3.511610     186.130520  5.783882e+18
# std      1964.764593       0.0       1.586912     149.011073  3.324016e+18
# min       109.000000     301.0       1.000000      11.000000  2.995191e+17
# 25%      3187.000000     301.0       2.000000      82.000000  2.844138e+18
# 50%      4188.000000     301.0       4.000000     146.000000  5.614883e+18
# 75%      5326.000000     301.0       5.000000     241.000000  8.332144e+18
# max      8162.000000     301.0       6.000000     989.000000  1.412694e+19
#
#             redshift          plate            MJD       fiber_ID
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.576661    5137.009660   55588.647500     449.312740
# std         0.730707    2952.303351    1808.484233     272.498404
# min        -0.009971     266.000000   51608.000000       1.000000
# 25%         0.054517    2526.000000   54234.000000     221.000000
# 50%         0.424173    4987.000000   55868.500000     433.000000
# 75%         0.704154    7400.250000   56777.000000     645.000000
# max         7.011245   12547.000000   58932.000000    1000.000000

# %%
sbs.countplot(x="class",data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
df['class'] = df['class'].map({'GALAXY': 0, 'QSO': 1, 'STAR': 2})

# %%
df
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0      19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1      21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2      19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3      20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4      15.97711  15.54461    8102       301        3       137  6.891865e+18
# ...         ...       ...     ...       ...      ...       ...           ...
# 99995  21.30548  20.73569    7778       301        2       581  1.055431e+19
# 99996  19.75759  19.41526    7917       301        1       289  8.586351e+18
# 99997  17.69034  17.35221    5314       301        4       308  3.112008e+18
# 99998  19.07254  18.62482    3650       301        4       131  7.601080e+18
# 99999  20.00959  19.28075    3650       301        4        60  8.343152e+18
#
#        class  redshift  plate    MJD  fiber_ID
# 0          0  0.634794   5812  56354       171
# 1          0  0.779136  10445  58158       427
# 2          0  0.644195   4576  55592       299
# 3          0  0.932346   9149  58039       775
# 4          0  0.116123   6121  56187       842
# ...      ...       ...    ...    ...       ...
# 99995      0  0.000000   9374  57749       438
# 99996      0  0.404895   7626  56934       866
# 99997      0  0.143366   2764  54535        74
# 99998      0  0.455040   6751  56368       470
# 99999      0  0.542944   7410  57104       851
#
# [100000 rows x 18 columns]

# %%
len(df)
# Out:
# 100000

# %%
plt.figure(figsize=(10,6))
df.corr()["class"].sort_values().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sbs.countplot(x="rerun_ID",data=df)
# Out:
# <AxesSubplot:xlabel='rerun_ID', ylabel='count'>

# %%
df=df.drop("rerun_ID",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4908\3951183653.py in <module>
# ----> 1 df=df.drop("rerun_ID",axis=1)
#       2 df.corr()["class"].sort_values()
#
# D:\Anaconda\envs\p-t8\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\Anaconda\envs\p-t8\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# D:\Anaconda\envs\p-t8\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# D:\Anaconda\envs\p-t8\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# D:\Anaconda\envs\p-t8\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['rerun_ID'] not found in axis"

# %%
df.corr()["class"].sort_values()
# Out:
# r             -0.076766
# redshift      -0.054239
# fiber_ID      -0.041586
# run_ID        -0.036014
# obj_ID        -0.036012
# field_ID      -0.034833
# u             -0.024645
# g             -0.020066
# alpha         -0.011756
# spec_obj_ID   -0.010060
# plate         -0.010060
# z             -0.001614
# MJD           -0.000405
# delta          0.014452
# i              0.015028
# cam_col        0.023138
# class          1.000000
# Name: class, dtype: float64

# %%
y=df["class"].values

# %%
x=df.drop("class",axis=1).values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train ,y_test=train_test_split(x,y , test_size=0.25 , random_state=25)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
x_train.shape
# Out:
# (75000, 16)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# %%
model = Sequential([
    Dense(128, activation='relu'),
    Dropout(0.3),  
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(3, activation='softmax') 
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
 model.fit(x_train, y_train,
                    validation_data=(x_test, y_test),
                    epochs=50,
                    batch_size=64,
                    callbacks=[early_stop])
# Out:
# Epoch 1/50
# 1172/1172 [==============================] - 8s 5ms/step - loss: 0.5172 - accuracy: 0.7906 - val_loss: 0.3461 - val_accuracy: 0.8517
# Epoch 2/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2633 - accuracy: 0.9119 - val_loss: 0.3238 - val_accuracy: 0.8631
# Epoch 3/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2159 - accuracy: 0.9317 - val_loss: 0.2466 - val_accuracy: 0.9116
# Epoch 4/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1972 - accuracy: 0.9390 - val_loss: 0.2580 - val_accuracy: 0.9018
# Epoch 5/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1878 - accuracy: 0.9423 - val_loss: 0.3150 - val_accuracy: 0.8863
# Epoch 6/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1791 - accuracy: 0.9463 - val_loss: 0.2669 - val_accuracy: 0.9012
# Epoch 7/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1737 - accuracy: 0.9473 - val_loss: 0.2509 - val_accuracy: 0.9089
# Epoch 8/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1693 - accuracy: 0.9488 - val_loss: 0.2452 - val_accuracy: 0.9148
# Epoch 9/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1653 - accuracy: 0.9506 - val_loss: 0.2432 - val_accuracy: 0.9146
# Epoch 10/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1596 - accuracy: 0.9524 - val_loss: 0.2170 - val_accuracy: 0.9228
# Epoch 11/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1608 - accuracy: 0.9525 - val_loss: 0.2305 - val_accuracy: 0.9228
# Epoch 12/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1573 - accuracy: 0.9526 - val_loss: 0.2298 - val_accuracy: 0.9260
# Epoch 13/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1575 - accuracy: 0.9527 - val_loss: 0.2430 - val_accuracy: 0.9108
# Epoch 14/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1534 - accuracy: 0.9542 - val_loss: 0.2127 - val_accuracy: 0.9332
# Epoch 15/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1533 - accuracy: 0.9535 - val_loss: 0.2366 - val_accuracy: 0.9229
# Epoch 16/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1497 - accuracy: 0.9546 - val_loss: 0.2576 - val_accuracy: 0.9098
# Epoch 17/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1495 - accuracy: 0.9559 - val_loss: 0.2432 - val_accuracy: 0.9172
# Epoch 18/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1464 - accuracy: 0.9563 - val_loss: 0.2026 - val_accuracy: 0.9459
# Epoch 19/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1465 - accuracy: 0.9566 - val_loss: 0.2162 - val_accuracy: 0.9318
# Epoch 20/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1457 - accuracy: 0.9564 - val_loss: 0.2380 - val_accuracy: 0.9152
# Epoch 21/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1435 - accuracy: 0.9570 - val_loss: 0.2343 - val_accuracy: 0.9210
# Epoch 22/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1444 - accuracy: 0.9573 - val_loss: 0.2304 - val_accuracy: 0.9327
# Epoch 23/50
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1424 - accuracy: 0.9577 - val_loss: 0.2614 - val_accuracy: 0.9146

# %%
loss=pd.DataFrame(model.history.history)

# %%
loss.plot()
# Out:
# <AxesSubplot:>

# %%
deneme=model.predict(x_test)
# Out:
# 782/782 [==============================] - 2s 2ms/step

# %%
y_tahmin = np.argmax(deneme, axis=1)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test, y_tahmin))
print(confusion_matrix(y_test, y_tahmin))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96     14918
#            1       0.98      0.81      0.89      4676
#            2       0.93      1.00      0.96      5406
#
#     accuracy                           0.95     25000
#    macro avg       0.95      0.93      0.94     25000
# weighted avg       0.95      0.95      0.94     25000
#
# [[14445    70   403]
#  [  875  3799     2]
#  [    2     0  5404]]
