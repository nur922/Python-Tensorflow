# %%
import numpy as np
import pandas as pd
import seaborn as sbn 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Laptop_price.csv")

# %%
df
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0      Asus         3.830296        16               512    11.185147
# 1      Acer         2.912833         4              1000    11.311372
# 2    Lenovo         3.241627         4               256    11.853023
# 3      Acer         3.806248        16               512    12.280360
# 4      Acer         3.268097        32              1000    14.990877
# ..      ...              ...       ...               ...          ...
# 995      HP         3.343584         4              1000    12.587095
# 996    Dell         2.780555         8               256    12.679356
# 997    Dell         3.200569         4               512    12.666315
# 998    Asus         1.604182         8               256    11.215581
# 999  Lenovo         1.711980         4               256    16.561498
#
#        Weight         Price
# 0    2.641094  17395.093065
# 1    3.260012  31607.605919
# 2    2.029061   9291.023542
# ...

# %%
df.describe()
# Out:
#        Processor_Speed     RAM_Size  Storage_Capacity  Screen_Size  \
# count      1000.000000  1000.000000       1000.000000  1000.000000
# mean          2.750611    15.500000        584.576000    14.056790
# std           0.731796    10.988665        313.438517     1.705882
# min           1.511580     4.000000        256.000000    11.012111
# 25%           2.089246     8.000000        256.000000    12.635523
# 50%           2.760885    16.000000        512.000000    14.099643
# 75%           3.362610    32.000000       1000.000000    15.528590
# max           3.998534    32.000000       1000.000000    16.985737
#
#             Weight         Price
# count  1000.000000   1000.000000
# mean      3.466919  19604.187963
# std       0.866541   9406.064880
# min       2.000560   8570.012950
# 25%       2.717211  10114.012948
# 50%       3.464630  17287.241878
# 75%       4.212583  31566.214754
# max       4.990728  33503.935037

# %%
df.isnull().sum()
# Out:
# Brand               0
# Processor_Speed     0
# RAM_Size            0
# Storage_Capacity    0
# Screen_Size         0
# Weight              0
# Price               0
# dtype: int64

# %%
len(df)
# Out:
# 1000

# %%
df.sort_values("Price" ,ascending=False).head(10)
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 424  Lenovo         3.877159        32              1000    13.783941
# 610    Dell         3.610426        32              1000    14.985210
# 302    Dell         3.448961        32              1000    15.637920
# 338    Acer         3.208147        32              1000    16.890244
# 574    Acer         3.928488        32              1000    14.783486
# 816    Dell         2.832394        32              1000    14.488503
# 989      HP         3.737794        32              1000    13.013740
# 858    Dell         1.719107        32              1000    16.386461
# 885      HP         3.939026        32              1000    12.498633
# 889    Asus         3.655036        32              1000    16.568611
#
#        Weight         Price
# 424  3.561348  33503.935037
# 610  2.073854  33489.969689
# 302  3.356260  33459.847493
# 338  3.675057  33370.442080
# 574  3.154198  33354.902596
# ...

# %%
df.corr()["Price"].sort_values()
# Out:
# Processor_Speed    -0.050737
# Screen_Size        -0.026740
# Weight              0.038417
# RAM_Size            0.061237
# Storage_Capacity    0.997908
# Price               1.000000
# Name: Price, dtype: float64

# %%
df.groupby("Storage_Capacity").mean()["Price"]
# Out:
# Storage_Capacity
# 256      9764.373384
# 512     17430.993066
# 1000    32044.618434
# Name: Price, dtype: float64

# %%
df.groupby("Storage_Capacity").count()
# Out:
#                   Brand  Processor_Speed  RAM_Size  Price
# Storage_Capacity
# 256                 357              357       357    357
# 512                 307              307       307    307
# 1000                336              336       336    336

# %%
sbn.histplot(df["Price"])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
sbn.scatterplot(x="Price" , y="Storage_Capacity" , data=df)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Storage_Capacity'>

# %%
df=df.drop(["Screen_Size","Weight"] ,axis=1)
df
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity         Price
# 0      Asus         3.830296        16               512  17395.093065
# 1      Acer         2.912833         4              1000  31607.605919
# 2    Lenovo         3.241627         4               256   9291.023542
# 3      Acer         3.806248        16               512  17436.728334
# 4      Acer         3.268097        32              1000  32917.990718
# ..      ...              ...       ...               ...           ...
# 995      HP         3.343584         4              1000  31593.668017
# 996    Dell         2.780555         8               256   9149.521832
# 997    Dell         3.200569         4               512  16552.404779
# 998    Asus         1.604182         8               256   9407.473459
# 999  Lenovo         1.711980         4               256   8807.696702
#
# [1000 rows x 5 columns]

# %%
df.sort_values("Price").head(10)
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity        Price
# 425      HP         1.877645         4               256  8570.012950
# 888      HP         1.831312         4               256  8771.368296
# 899  Lenovo         1.670431         4               256  8780.660812
# 900  Lenovo         1.564530         4               256  8807.456312
# 999  Lenovo         1.711980         4               256  8807.696702
# 833    Dell         2.625927         4               256  8836.578529
# 322      HP         2.164000         4               256  8909.468098
# 911  Lenovo         2.040095         4               256  8921.533462
# 562    Acer         2.192069         4               256  8931.641590
# 336    Dell         1.702616         4               256  8938.607532

# %%
df=df.sort_values("Price",ascending=False).iloc[10:]
df
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity         Price
# 230      HP         3.655107        32              1000  33229.673458
# 375  Lenovo         3.952965        32              1000  33201.854448
# 640    Asus         2.269825        32              1000  33188.923153
# 53     Acer         2.988463        32              1000  33151.040942
# 497    Dell         3.223662        32              1000  33137.460963
# ..      ...              ...       ...               ...           ...
# 828      HP         1.938257         8               256   8962.711433
# 627      HP         1.870858         8               256   8960.497200
# 474  Lenovo         3.237455         4               256   8957.611389
# 634    Dell         2.636850         4               256   8951.260151
# 813    Dell         2.850030         4               256   8946.643611
#
# [980 rows x 5 columns]

# %%
df.corr()["Price"]
# Out:
# Processor_Speed    -0.078939
# RAM_Size            0.028203
# Storage_Capacity    0.997991
# Price               1.000000
# Name: Price, dtype: float64

# %%
y=df["Price"].values

# %%
x=df.drop(["Price","Brand"], axis=1).values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test,y_train,y_test=train_test_split(x,y , test_size=0.33 , random_state=50)

# %%
x_train
# Out:
# array([[   1.88006213,    4.        ,  512.        ],
#        [   3.99174213,   16.        , 1000.        ],
#        [   2.7805548 ,    8.        ,  256.        ],
#        ...,
#        [   2.18314882,    8.        ,  256.        ],
#        [   3.23758807,   16.        ,  512.        ],
#        [   1.71414562,   32.        ,  256.        ]])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
x_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.fit_transform(x_test)

# %%
x_train.shape
# Out:
# (656, 3)

# %%
x_test
# Out:
# array([[0.27183893, 0.14285714, 0.        ],
#        [0.50172637, 0.14285714, 0.        ],
#        [0.29411671, 0.14285714, 0.34408602],
#        [0.06324338, 1.        , 0.34408602],
#        [0.1335862 , 0.42857143, 0.34408602],
#        [0.24612462, 0.        , 0.34408602],
#        [0.89700227, 0.        , 0.        ],
#        [0.38167367, 0.        , 1.        ],
#        [0.0561009 , 0.42857143, 1.        ],
#        [0.85686341, 0.        , 0.        ],
#        [0.4477773 , 1.        , 0.        ],
#        [0.45350857, 0.42857143, 0.34408602],
#        [0.14902058, 0.        , 1.        ],
#        [0.48070104, 1.        , 0.34408602],
#        [0.4713462 , 0.42857143, 0.        ],
#        [0.27178394, 0.14285714, 0.        ],
#        [0.66020031, 0.42857143, 1.        ],
#        [0.3948169 , 0.14285714, 0.        ],
#        [0.27023441, 0.14285714, 1.        ],
#        [0.2427313 , 0.42857143, 0.        ],
#        [0.61569653, 1.        , 0.        ],
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(18, activation="relu"))
model.add(Dense(15, activation="relu"))
model.add(Dense(12, activation="relu"))
model.add(Dense(9, activation="relu"))
model.add(Dense(6, activation="relu"))
model.add(Dense(3, activation="relu"))
model.add(Dense(1))

model.compile(optimizer="adam" , loss="mse")

# %%
model.fit(x=x_train , y=y_train, validation_data=(x_test,y_test), batch_size=100 , epochs=150)
# Out:
# Epoch 1/150
# 7/7 [==============================] - 1s 44ms/step - loss: 480008544.0000 - val_loss: 450331168.0000
# Epoch 2/150
# 7/7 [==============================] - 0s 6ms/step - loss: 480001888.0000 - val_loss: 450323936.0000
# Epoch 3/150
# 7/7 [==============================] - 0s 6ms/step - loss: 479993408.0000 - val_loss: 450314400.0000
# Epoch 4/150
# 7/7 [==============================] - 0s 6ms/step - loss: 479981920.0000 - val_loss: 450301408.0000
# Epoch 5/150
# 7/7 [==============================] - 0s 8ms/step - loss: 479965824.0000 - val_loss: 450283296.0000
# Epoch 6/150
# 7/7 [==============================] - 0s 8ms/step - loss: 479943904.0000 - val_loss: 450257600.0000
# Epoch 7/150
# 7/7 [==============================] - 0s 7ms/step - loss: 479912288.0000 - val_loss: 450220928.0000
# Epoch 8/150
# 7/7 [==============================] - 0s 7ms/step - loss: 479867776.0000 - val_loss: 450168000.0000
# Epoch 9/150
# ...

# %%
loss=pd.DataFrame(model.history.history)

# %%
loss.plot()
# Out:
# <AxesSubplot:>

# %%
deney=model.predict(x_test)
# Out:
# 11/11 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error

# %%
mean_absolute_error(y_test,deney)
# Out:
# 212.067005137341

# %%
plt.scatter(y_test,deney)
plt.plot(y_test,y_test,"r-*")

# %%
df.iloc[5]
# Out:
# Brand                       Asus
# Processor_Speed         3.987166
# RAM_Size                      32
# Storage_Capacity            1000
# Price               33122.000193
# Name: 919, dtype: object

# %%
veri=df.drop(["Brand","Price"],axis=1).iloc[5]

# %%
veri=scaler.transform(veri.values.reshape(-1,3))
veri
# Out:
# array([[0.99852012, 1.        , 1.        ]])

# %%
model.predict(veri)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# array([[32724.713]], dtype=float32)
